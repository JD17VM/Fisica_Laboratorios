# %% [markdown]
# <a href="https://colab.research.google.com/github/JD17VM/Fisica_Laboratorios/blob/main/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Estudiante:** Juan Diego Valdivia Mendoza

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **Resolución de la Ecuación del Trabajo para una Fuerza Variable**

# %% [markdown]
# La tercera ley de Newton, conocida también como la ley de acción y reacción, establece que “para cada acción, hay una reacción igual y opuesta”. Sin embargo, cuando se trata de resolver problemas relacionados con el trabajo realizado por una fuerza variable, se utiliza el concepto de trabajo en física.

# %% [markdown]
# ## **Trabajo**
#
# El trabajo es una medida de la energía transferida a un objeto cuando se aplica una fuerza sobre él y éste se desplaza. Matemáticamente, el trabajo 𝑊 *se* define como:

# %% [markdown]
# ## **Métodos Numéricos**
# Dado que en muchos casos no podemos obtener una solución analítica (exacta) para la integral del trabajo, utilizamos métodos numéricos para aproximar el valor del trabajo. Uno de los métodos más comunes es la regla del trapecio, que divide el área bajo la curva en pequeños trapecios y suma sus áreas.

# %%
# Definición de la función de fuerza variable
def fuerza_variable(x):
    return 5 * x

# Definición de la función para calcular el trabajo usando la regla del trapecio
def calcular_trabajo(fuerza, a, b, n):
    x = np.linspace(a, b, n+1)  # Dividimos el intervalo en n subintervalos
    dx = (b - a) / n  # Diferencial de x (dr)
    trabajo = 0.5 * dx * (fuerza(x[0]) + 2 * np.sum(fuerza(x[1:-1])) + fuerza(x[-1]))
    return trabajo

# %%
a = 0  # Límite inferior de la integral
b = 10  # Límite superior de la integral
n = 100  # Número de subdivisiones

# Calculo de el trabajo
trabajo = calcular_trabajo(fuerza_variable, a, b, n)
print(f"El trabajo realizado es: {trabajo:.2f} J")
# Out:
# El trabajo realizado es: 250.00 J

# %%
x = np.linspace(a, b, 100)
fuerza = fuerza_variable(x)
plt.plot(x, fuerza, label='Fuerza variable')
plt.fill_between(x, fuerza, alpha=0.3)
plt.title('Fuerza Variable vs. Desplazamiento')
plt.xlabel('Desplazamiento (m)')
plt.ylabel('Fuerza (N)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Explicación del Código**
#
# 1.   **Función de fuerza variable:** Definimos la función de fuerza como dependiente de la posición 𝑥 En este caso, es una fuerza lineal (5 * x), pero se puede cambiar
# 2.   **Regla del trapecio:** La función calcular_trabajo implementa el cálculo del trabajo usando la regla del trapecio, dividiendo el intervalo en 𝑛 subintervalos y sumando las áreas de los trapecios formados.
# 3.   **Gráfica de la Fuerza Variable:** Se genera una gráfica que muestra cómo varía la fuerza en función del desplazamiento.

# %% [markdown]
# ## **Conclusión**
#
# A través de este ejercicio, hemos demostrado cómo utilizar el método numérico del trapecio para calcular el trabajo realizado por una fuerza variable. Este método es útil cuando no podemos calcular la integral analíticamente y proporciona una solución precisa basada en aproximaciones.
